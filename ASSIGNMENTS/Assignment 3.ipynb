# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("1.Add  2.Subtract  3.Multiply  4.Divide  5.Power")
choice = int(input("Choose operation: "))

if choice == 1:
    print("Result =", num1 + num2)
elif choice == 2:
    print("Result =", num1 - num2)
elif choice == 3:
    print("Result =", num1 * num2)
elif choice == 4:
    print("Result =", num1 / num2)
elif choice == 5:
    print("Result =", num1 ** num2)
else:
    print("Invalid choice")
# Out:
# Enter first number:  37
# Enter second number:  45
# 1.Add  2.Subtract  3.Multiply  4.Divide  5.Power
# Choose operation:  2
# Result = -8.0

# %%
my_list = [10, "hi", 5.5, "abc"]

found = False

for item in my_list:
    if isinstance(item, (int, float)):
        found = True
        break

if found:
    print("Numeric value exists")
else:
    print("No numeric value found")
# Out:
# Numeric value exists

# %%
my_dict = {"name": "Ali", "age": 10}

key = input("Enter key: ")
value = input("Enter value: ")

my_dict[key] = value

print("Updated dictionary:", my_dict)
# Out:
# Enter key:  grade
# Enter value:  5
# Updated dictionary: {'name': 'Ali', 'age': 10, 'grade': '5'}

# %%
my_dict = {"a": 10, "b": 26, "c": "hello", "d": 15}

total = 0

for value in my_dict.values():
    if isinstance(value, (int, float)):
        total += value

print("Sum =", total)
# Out:
# Sum = 51

# %%
my_list = [1, 2, 3, 2, 4, 5, 1, 6, 0]

duplicates = []

for item in my_list:
    if my_list.count(item) > 1 and item not in duplicates:
        duplicates.append(item)

print("Duplicate values:", duplicates)
# Out:
# Duplicate values: [1, 2]
